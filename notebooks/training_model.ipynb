# %%
from src.load_data import load_data
import pandas as pd

path = '../data/processed/airbnb-processed.csv'

df = load_data(path)

df
# Out:
#          rating reviews                                            address  \
# 0      4.710000      64                           Kartepe, Kocaeli, Turkey
# 1      4.857475       0                               Kaş, Antalya, Turkey
# 2      4.850000      68                                   Imereti, Georgia
# 3      5.000000      13                           Sapanca, Sakarya, Turkey
# 4      4.857475       0                           Sapanca, Sakarya, Turkey
# ...         ...     ...                                                ...
# 12800  4.940000      16  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 12801  4.670000       6                                 Gianyar, Indonesia
# 12802  4.670000       3                                     Kabale, Uganda
# 12803  4.860000       7        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 12804  4.850000      13                              Uruma, Okinawa, Japan
#
#        price  bathrooms  beds  guests  toiles  bedrooms  studios  has_rating
# 0       8078          1     2       2       0         2        0           1
# 1       4665          2     2       4       0         2        0           0
# 2       5991          1     1       4       0         1        0           1
# 3      11339          1     1       4       0         1        0           1
# 4       6673          1     1       2       0         1        0           0
# ...      ...        ...   ...     ...     ...       ...      ...         ...
# 12800   4288          8     0       4       0         0        0           1
# 12801  15200          0     1       2       1         1        0           1
# 12802   9103          0     1       2       0         1        0           1
# 12803  42262          5     2       8       0         2        0           1
# 12804   9909          1     1       5       0         1        0           1
#
# [12805 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12805 entries, 0 to 12804
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rating      12805 non-null  float64
#  1   reviews     12805 non-null  object
#  2   address     12805 non-null  object
#  3   price       12805 non-null  int64
#  4   bathrooms   12805 non-null  int64
#  5   beds        12805 non-null  int64
#  6   guests      12805 non-null  int64
#  7   toiles      12805 non-null  int64
#  8   bedrooms    12805 non-null  int64
#  9   studios     12805 non-null  int64
#  10  has_rating  12805 non-null  int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 1.1+ MB

# %%
print(df['reviews'].unique())
# Out:
# ['64' '0' '68' '13' '3' '77' '55' '116' '23' '21' '8' '52' '17' '61' '49'
#  '38' '4' '15' '26' '5' '2' '85' '9' '20' '11' '7' '1' '241' '41' '10'
#  '25' '154' '44' '19' '58' '137' '33' '12' '18' '16' '113' '125' '42'
#  '244' '27' '188' '34' '69' '97' '6' '86' '114' '65' '91' '32' '53' '231'
#  '99' '14' '120' '29' '28' '22' '123' '90' '124' '110' '79' '93' '54' '59'
#  '74' '31' '48' '30' '89' '92' '35' '24' '229' '40' '102' '39' '194' '100'
#  '147' '37' '78' '88' '71' '130' '576' '1,003' '261' '726' '127' '76' '84'
#  '36' '60' '192' '46' '135' '62' '159' '158' '45' '95' '104' '211' '43'
#  '121' '109' '210' '107' '98' '310' '96' '73' '50' '82' '66' '943' '254'
#  '571' '72' '51' '246' '136' '165' '67' '807' '262' '548' '266' '181'
#  '141' '171' '271' '160' '56' '608' '346' '174' '316' '215' '87' '112'
#  '173' '144' '238' '675' '201' '161' '57' '81' '239' '328' '193' '151'
#  '237' '111' '268' '149' '138' '420' '47' '221' '219' '146' '63' '189'
#  '162' '152' '80' '222' '70' '133' '75' '208' '195' '167' '170' '156'
#  '108' '94' '166' '214' '286' '212' '105' '290' '117' '126' '543' '249'
#  '169' '119' '180' '183' '172' '83' '276' '142' '385' '134' '393' '150'
#  '475' '379' '277' '199' '177' '299' '370' '364' '234' '380' '255' '140'
#  '780' '252' '473' '186' '205' '213' '103' '232' '143' '175' '163' '259'
#  '484' '329' '139' '118' '716' '532' '519' '308' '317' '258' '339' '115'
#  '128' '476' '176' '285' '182' '275' '553' '703' '278' '549' '185' '340'
#  '493' '448' '164' '157' '318' '168' '223' '106' '101' '302' '545' '153'
#  '455' '517' '248' '284' '148' '129' '273' '264' '187' '377' '295' '311'
#  '353' '131' '200' '337' '555' '538' '243' '233' '256' '351' '291' '184'
#  '253' '263' '642' '216' '269' '132' '240' '242' '247' '250' '122' '145'
#  '338' '489' '265' '315' '320' '342' '217' '179' '204' '218' '440' '228'
#  '371' '306' '230' '191' '361' '304' '347' '296' '456' '236' '419' '155'
#  '196' '209' '197' '297' '433' '270' '206' '330' '332' '363' '378' '348'
#  '331' '279' '485' '300' '178' '373' '354' '326' '207' '305' '224' '198'
#  '225' '202' '499' '434' '410' '541' '439' '369' '390' '288' '282' '226'
#  '274' '313' '303' '251' '292' '386' '203' '423' '190' '504' '469' '235'
#  '374' '319' '245' '352' '220' '325' '321' '272' '260' '227' '492' '497'
#  '350' '406' '280' '665' '638' '324' '570' '496' '529' '294' '516' '407'
#  '355' '362' '444' '417' '524' '257' '510' '359' '267']

# %%
df['reviews'] = pd.to_numeric(df['reviews'], errors='coerce')
df['reviews'] = df['reviews'].fillna(0).astype(int)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
 
X_train, X_test, y_train, y_test = train_test_split(
        df.drop(columns=['price', 'address']),
        df['price'],
        test_size=0.2,
        random_state=42
    )

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model_lr.score(X_train, y_train),
model_lr.score(X_test, y_test)
# Out:
# 0.07204190875472904
